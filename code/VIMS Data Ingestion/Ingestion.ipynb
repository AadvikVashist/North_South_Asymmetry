# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import os
import numpy as np
import time
import urllib.request
from pprint import pprint
from html_table_parser.parser import HTMLTableParser
# for converting the parsed data in a
# pandas dataframe
import pandas as pd

# %%
baseurl = 'https://vims.univ-nantes.fr'
searchurl = 'https://vims.univ-nantes.fr/target/titan'


def parse_directory_for_links(search_directory):
    reqs = requests.get(searchurl)
    soup = BeautifulSoup(reqs.text, 'html.parser')
    abc = soup.find_all('a')
    allurls = [link.get('href') for link in abc]
    # url filtering
    urls = []
    for link in allurls:
        if "/flyby" in link:
            urls.append(link)
    if urls:
        print("found flybys")
    else:
        print("no flybys found")
    return urls


urls = parse_directory_for_links(searchurl)
# Out:
# found flybys

# %%
def url_get_contents(url):
    req = urllib.request.Request(url=url)
    f = urllib.request.urlopen(req)
    # reading contents of the website
    return f.read()

def list_all_tables(urllist):
    p = HTMLTableParser()
    start = time.time()
    length = len(urllist)
    for index,url in enumerate(urllist):
        html = url_get_contents(os.path.join(baseurl+url)).decode('utf-8')
        p.feed(html)
        end = time.time() - start
        print(url, "passed time",end ,  "/",index/length*end, " seconds")
    return [p.tables], np.array(p.tables)[0]
flybylist, flybyarray = list_all_tables(urls)
# Out:
# /flyby/000TI
# /flyby/00ATI
# /flyby/00BTI
# /flyby/003TI
# /flyby/005TI
# /flyby/006TI
# /flyby/009TI
# /flyby/013TI
# /flyby/014TI
# /flyby/017TI
# /flyby/019TI
# /flyby/020TI
# /flyby/021TI
# /flyby/022TI
# /flyby/023TI
# /flyby/024TI
# /flyby/025TI
# /flyby/026TI
# /flyby/028TI
# /flyby/029TI
# /flyby/030TI
# /flyby/031TI
# /flyby/035TI
# /flyby/036TI
# /flyby/037TI
# /flyby/038TI
# /flyby/039TI
# /flyby/040TI
# /flyby/041TI
# /flyby/042TI
# /flyby/043TI
# /flyby/044TI
# /flyby/045TI
# /flyby/046TI
# /flyby/047TI
# /flyby/048TI
# /flyby/049TI
# /flyby/050TI
# /flyby/051TI
# /flyby/052TI
# /flyby/053TI
# /flyby/054TI
# /flyby/055TI
# /flyby/059TI
# /flyby/062TI
# /flyby/063TI
# /flyby/066TI
# /flyby/067TI
# /flyby/069TI
# /flyby/071TI
# /flyby/072TI
# /flyby/078TI
# /flyby/091TI
# /flyby/093TI
# /flyby/095TI
# /flyby/096TI
# /flyby/097TI
# /flyby/098TI
# /flyby/100TI
# /flyby/102TI
# /flyby/103TI
# /flyby/106TI
# /flyby/107TI
# /flyby/108TI
# /flyby/109TI
# /flyby/110TI
# ...

# %%
def url_get_contents(url):
    req = urllib.request.Request(url=url)
    f = urllib.request.urlopen(req)
    # reading contents of the website
    return f.read()

def list_all_tables(urllist):
    p = HTMLTableParser()
    start = time.time()
    length = len(urllist)
    for index,url in enumerate(urllist):
        html = url_get_contents(os.path.join(baseurl+url)).decode('utf-8')
        p.feed(html)
        end = time.time() - start
        if index > 0:
            print(url, "passed time",end ,  "/",length/index*end, " seconds")
    return [p.tables], np.array(p.tables)[0]
list_all_tables(urls)
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In [9], line 17
#      15         print(url, "passed time",end ,  "/",length/index*end, " seconds")
#      16     return [p.tables], np.array(p.tables)[0]
# ---> 17 list_all_tables(urls)
#
# Cell In [9], line 15, in list_all_tables(urllist)
#      13     p.feed(html)
#      14     end = time.time() - start
# ---> 15     print(url, "passed time",end ,  "/",length/index*end, " seconds")
#      16 return [p.tables], np.array(p.tables)[0]
#
# ZeroDivisionError: division by zero

# %%
data = [p.tables]
datanp = np.array(data)[0]
print(datanp.shape)
a = datanp[:, :, 0]
b = datanp[0, :, 0]
row1 = datanp[0, :, 0]
for table in data:
    urls = urls
